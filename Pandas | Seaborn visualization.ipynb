# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Pandas | Seaborn visualization

# %% [markdown]
# We'll be working with a data set of the passengers of the Titanic. <br>
# __The data set was compiled by Kaggle for their introductory data science competition, called Titanic: Machine Learning from Disaster.__ <br>
# The goal of the competition is to build machine learning models that can predict if a passenger survives from their attributes. <br>
# You can download the data set by navigating to the data download page for the competition and creating a free account.

# %% [markdown]
# ### Instructions
#
# 1. Read train.csv into a DataFrame named titanic. Keep only the following columns:
#     - `"Survived"`
#     - `"Pclass"`
#     - `"Sex"`
#     - `"Age"`
#     - `"SibSp"`
#     - `"Parch"`
#     - `"Fare"`
#     - `"Embarked"`
# 2. __Use the DataFrame.dropna( )__ method to remove rows containing missing values.

# %%
titanic = pd.read_csv('train.csv')
titanic_bool = ["Survived", "Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]
titanic = titanic[titanic_bool]
titanic = titanic.dropna(axis=0) #  to remove rows

# %%
titanic.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### Instructions
#
# 1. __Import `seaborn as sns` and `matplotlib.pyplot as plt`__.
# 2. Use the __`seaborn.distplot()`__ function to visualize the distribution of the `"Age"` column.

# %%
import seaborn as sns    # seaborn is commonly imported as `sns`
import matplotlib.pyplot as plt
sns.distplot(titanic["Age"]);

# %% [markdown]
# ### Instructions
#
# 1. Generate a kernel density plot:
#     - Using the values in the `"Age"` column
#      - With the area under the curve shaded
# 2. Set the x-axis label to `"Age"` using `pyplot.xlabel()`.

# %%
sns.kdeplot(titanic["Age"], shade=True).set_xlabel("Age");

# %%
sns.kdeplot(titanic['Age'], shade=True)
plt.xlabel("Age");

# %% [markdown]
# ### Instructions
# 1. Set the style to the style sheet that hides the coordinate grid and __sets the background color to white__.
# 2. Generate a kernel density plot of the "Age" column, with the area under the curve shaded.
# 3. Set the x-axis label to "Age".
# 4. __Despine all of the axes__.

# %%
sns.kdeplot(titanic['Age'], shade=True)
sns.set_style("white")
sns.despine(left='True', bottom='True')
plt.xlabel("Age");

# %% [markdown]
# ### Instructions
#
# 1. Use a FacetGrid instance to generate three plots on the same row:
#     - One for each unique value of Pclass.
#     - Each plot should be a kernel density plot of the "Age" column, with the area under the curve shaded.
#     - Each plot should have a height of 6 inches.
# 2. Remove all of the spines using __`seaborn.despine()`__.

# %%
g = sns.FacetGrid(titanic, col="Pclass", height=6)
g.map(sns.kdeplot, "Age", shade=True).despine(left='True', bottom='True');

# %%
# titanic_bool = ["Survived", "Pclass", "Sex", "Age", "SibSp", "Parch", "Fare", "Embarked"]

g = sns.FacetGrid(titanic, col="SibSp", height=6)
g.map(sns.kdeplot, "Age", shade=True).despine(left='True', bottom='True');

# %% [markdown]
# ### Instructions
#
# 1. Use a FacetGrid instance to generate a grid of plots using the following conditions:
#     - The Survived column across the columns in the grid.
#     - The Pclass column across the rows in the grid.
#     - __The Sex column using _`different hues`___.
# 2. Each plot should be a kernel density plot of the "Age" column, with the area under the curve shaded.
# 3. Each plot should have a height of 3 inches.
# 4. Remove all of the spines using __`seaborn.despine()`__.

# %%
g = sns.FacetGrid(titanic, col="Survived", row = "Pclass",  hue="Sex", height=3)
g.map(sns.kdeplot, "Age", shade=True).despine(left='True', bottom='True');

# %% [markdown]
# ### Instructions
#
# 1. Use a FacetGrid instance to generate a grid of plots using the following conditions:
#     - The Survived column across the columns in the grid.
#     - The Pclass column across the rows in the grid.
#     - The Sex column using different hues.
# 2. Each plot should be a kernel density plot of the "Age" column, with the area under the curve shaded.
# 3. Each plot should have a height of 3 inches.
# 4. Remove all of the spines using seaborn.despine().
# 5. Add a legend for the hues representing the values in the Sex column. Make sure that you add your legend after despining.

# %%
g = sns.FacetGrid(titanic, col="Survived", row = "Pclass",  hue="Sex", height=3)
g.map(sns.kdeplot, "Age", shade=True).despine(left='True', bottom='True')
g.add_legend();

# %% [markdown]
# ###  - - - done - - -
